# %%
import numpy as np
import matplotlib.pyplot as plt

from matrices_plotting import plot_two_axes, get_rotation_matrix_3d, plot_scatter_point, plot_vector

# %% [markdown]
# We have to place two frames in the plot and have freedom to place frame one. Frame two will be placed relative to frame one.
#
# For visualization convenience, we will place frame one on the origin. But please note that it can be placed anywhere in the plot.

# %%
Aorigin = np.array([0, 0, 0]) # Aorigin is the origin of frame A
# The size of the frame is 1 unit in each direction
X_A = np.array([1, 0, 0])
Y_A = np.array([0, 1, 0])
Z_A = np.array([0, 0, 1])

# %% [markdown]
# Now, we will place frame B relative to frame A. This information will be provided in the question.
#
# First, we place B frame at position vector, p, away from A frame.

# %%
# * offset of B origin from A origin (aka position vector, p)
p = o_9in5 = np.array([[0.28204963], [0.96161032], [0.35935391]])

# the code below is to flatten the list of lists for matplotlib plotting requirements 
Borigin_A = []
for sublist in p:
    Borigin_A.extend(sublist)
    
# Uncomment the line below if Aorigin is not at 0,0,0
# Borigin_A = Borigin_A + Aorigin

# %% [markdown]
# We can now Rotate frame B based on the rotation matrix provided in the question.
#
# This can be done by rotating about a fixed angle and axis. This would require us to calculate the rotation matrix.
#
# Or we can rotate frame B based on the Rotation matrix provided in the question.

# %%
# Rotation matrix provided in the problem
R_x = R_9in5 = np.array([[0.07155755, 0.13053746, 0.98885767], [0.99609913, -0.06067355, -0.06407215], [0.05163369, 0.98958511, -0.13436990]])

# %%
# Theta and axis provided in the problem
# axis = 'x'
# theta = np.pi/3
# R_x = R_9in5 = get_rotation_matrix_3d(axis, theta)

# %% [markdown]
# Now, depending on the question, a point or a vector will be provided in the question. We will first define and then plot this point/vector in the plot.

# %%
# point = q_44 = np.array([[-0.39428019], [-0.92702154], [-0.24232918]])

vector = v_5in5 = np.array([[-0.35180568], [0.16130314], [-0.31815458]])

# %% [markdown]
# Perform the operation on the point/vector as per the question, here.

# %%
R_5in9 = R_9in5.T # find inverse of R_9in5 by transpose

# translate evertyhing to cooordinate 9
v_9in5 = np.dot(R_5in9, v_5in5)

v_9in5
# Out:
# array([[ 0.11907207],
#        [-0.37055169],
#        [-0.31547038]])

# %% [markdown]
# The following code will plot the frames and the point/vector in the plot. We use a helper function file to do this. NOTE: set the points and vectors you want to plot manually because this varies based on the question.

# %%
X_B, Y_B, Z_B = np.dot(R_x, [X_A, Y_A, Z_A])

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plot_two_axes(ax, Aorigin, X_A, Y_A, Z_A, Borigin_A, X_B, Y_B, Z_B)
# plot_scatter_point(ax, point_1, True, Aorigin, Borigin_A, 'g', marker_shape='o')
# plot_scatter_point(ax, point_1, False, Aorigin, Borigin_A, 'pink', marker_shape='x')

# ".": point.
# "o": circle.
# "s": square.
# "^": triangle.
# "v": upside down triangle.
# "+": plus.
# "x": X.
plot_vector(ax, Aorigin, vector, 'c')
plot_vector(ax, Aorigin, v_9in5, 'y')


# ax.set_xlim([-2, 2])
# ax.set_ylim([-2, 2])
# ax.set_zlim([-2, 2])

plt.show()
